# %% [markdown]
# <h1 align = 'center'>Text Classification</h1>

# %% [markdown]
# <h3>Avinash Pasupulate</h3>
# <br>
# <a href='mailto:avinash.pasupulate@gmail.com'><i>avinash.pasupulate@gmail.com</i></a>

# %%
import os
import re
import copy
import string
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier


stopwrd = set(stopwords.words('english'))
cwd = os.getcwd()

# %% [markdown]
# Listing all files in directory

# %%
os.listdir(cwd+r'/data/reuters21578')
# Out:
# ['feldman-cia-worldfactbook-data.txt',
#  'all-orgs-strings.lc.txt',
#  'reut2-004.sgm',
#  'reut2-010.sgm',
#  'all-exchanges-strings.lc.txt',
#  'reut2-011.sgm',
#  'reut2-005.sgm',
#  'reut2-013.sgm',
#  'reut2-007.sgm',
#  'reut2-006.sgm',
#  'reut2-012.sgm',
#  'reut2-016.sgm',
#  'reut2-002.sgm',
#  'all-topics-strings.lc.txt',
#  'reut2-003.sgm',
#  'reut2-017.sgm',
#  'reut2-001.sgm',
#  'reut2-015.sgm',
#  'reut2-014.sgm',
#  'reut2-000.sgm',
#  'reut2-019.sgm',
#  'reut2-018.sgm',
#  'reut2-020.sgm',
#  'reut2-008.sgm',
#  'reut2-009.sgm',
#  'reut2-021.sgm',
#  'README.txt',
#  'all-people-strings.lc.txt',
#  'cat-descriptions_120396.txt',
#  'lewis.dtd',
#  'all-places-strings.lc.txt']

# %%
data = cwd+r'/data/reuters21578'

# %%
#creating a list of filenames to import

l = list(range(0,22))
m = []
for i in l:
    if len(str(i))==1:
        filename = '/reut2-00'+str(i)+'.sgm'
        m.append(filename)
    else:
        filename = '/reut2-0'+str(i)+'.sgm'
        m.append(filename)

# %%
#create dataframe with extracted text

doc = pd.DataFrame()
for i in m:
    with open(data+'/reut2-002.sgm', 'r') as f:
        text = BeautifulSoup(f.read(), 'html.parser')
        documents = text.findAll('reuters')
        l=[]
        for a in documents:
            try:
                topic = a.topics.find_all('d')[0].contents[0]
                place = a.places.find_all('d')[0].contents[0]
                title = a.title.contents[0].lower()
                body = re.sub('\n', ' ', a.body.contents[0].lower())
                l.append([topic, place, title, body])
            except:
                pass
        doc = doc.append(l, ignore_index = True, sort = True)
doc.columns = ['topic', 'place', 'title', 'body']

# %%
#doc

# %%
print("unique categories in text: {:} in {:} rows"
      .format(len(doc['topic'].unique()),len(doc['topic'])))
# Out:
# unique categories in text: 36 in 11220 rows

# %%
lemmatizer = WordNetLemmatizer()

def remnum(x):
    return re.sub('[0-9]', '', x)

def rempunc(x):
    return ''.join([w for w in x if w not in string.punctuation])

def cltxt(x):
    tok = [rempunc(remnum(i)) for i in x.split() 
     if (i not in stopwrd)]
    cltxt1 = [lemmatizer.lemmatize(i) for i in tok if len(i)>2]
    return ' '.join(i for i in cltxt1)

# %%
doc['body'] = doc['body'].apply(cltxt)
doc['title'] = doc['title'].apply(cltxt)

# %%
doc
# Out:
#               topic         place  \
# 0              earn            uk
# 1             grain           usa
# 2              earn           usa
# 3            copper         chile
# 4             crude        canada
# 5             grain           usa
# 6               acq        france
# 7              ship        turkey
# 8               acq           usa
# 9              earn        canada
# 10             earn        canada
# 11         money-fx            uk
# 12              acq           usa
# 13         money-fx           usa
# 14             earn           usa
# 15              acq           usa
# 16             earn           usa
# 17             earn        canada
# 18             earn           usa
# 19              acq           usa
# 20             earn           usa
# 21            grain        france
# 22            crude           usa
# 23             earn           usa
# 24             earn           usa
# 25             earn           usa
# 26              acq  west-germany
# 27             earn           usa
# 28             earn           usa
# 29             earn            uk
# ...             ...           ...
# 11190         crude       ecuador
# 11191          ship            uk
# 11192          ship       belgium
# 11193          earn      malaysia
# 11194          earn      malaysia
# 11195          earn      malaysia
# 11196          earn      malaysia
# 11197         sugar    bangladesh
# 11198           gnp  west-germany
# 11199      interest       bahrain
# 11200          ship            uk
# 11201         crude        turkey
# 11202          ship        brazil
# 11203         crude       ecuador
# 11204       tapioca      thailand
# 11205        cotton         china
# 11206         sugar          ussr
# 11207        rubber      thailand
# 11208       carcass     australia
# 11209      interest  west-germany
# 11210    iron-steel         japan
# 11211          gold     australia
# 11212         trade    bangladesh
# 11213           ipi   switzerland
# 11214      money-fx     singapore
# 11215  money-supply     singapore
# 11216           ipi         china
# 11217      money-fx   netherlands
# 11218         crude         japan
# 11219           acq            uk
#
#                                                 title  \
# 0             jaguar see strong growth new model sale
# 1              ccc accepts bonus bid wheat flour iraq
# 2                      nord resource corp nrd qtr net
# 3            quake damage chuquicamata mine spokesman
# 4                orbit increase oil gas reserve value
# 5                ccc accepts bonus bid semolina egypt
# 6         five group apply buy french telephone group
# 7                            blizzard close bosphorus
# 8           japan fund jpn seeker confident financing
# 9                  pegasus gold inc pgulf qtr dec net
# 10                                keltic inc year net
# 11           money market given help offered facility
# 12                 hutton efh start purolator pcc bid
# 13           yeutter put currency burden taiwan korea
# 14        princeville development corp pvdc year loss
# 15                        orangeco holder raise stake
# 16                           horizon corp hzn qtr net
# 17        international thomson organisation ltd year
# 18             equatorial communication equa qtr loss
# 19                     trimedyne tmed spin stake unit
# 20              caseys general store inc casy qtr jan
# 21      french free market cereal export bid detailed
# 22       diamond shamrock dia raise crude oil posting
# 23              oak hill sportswear corp ohsc qtr net
# 24                      oak industry inc oak qtr loss
# 25               regis corp rgis regular dividend set
# 26                         mannesmann seek stake firm
# 27                american intl group inc aig qtr net
# 28                    system health care onefor split
# 29            royal dutchshell earnings sharply lower
# ...                                               ...
# 11190          ecuador adopts austerity measure quake
# 11191     ferry disaster may rank among worst tragedy
# 11192                      almost dead ferry disaster
# 11193               sime darby bhd six month december
# 11194                     consolidated plantation bhd
# 11195                    tractor malaysia holding bhd
# 11196                   dunlop malaysian industry bhd
# 11197       bangladesh sugar production almost double
# 11198              german tax cut raised billion mark
# 11199                     yield fall day sama deposit
# 11200               expert expressed fear roro safety
# 11201           iraqturkey oil pipeline cut landslide
# 11202    brazil seaman continue strike court decision
# 11203          ecuador export oil four month official
# 11204   farm liberalisation seen hurting thai tapioca
# 11205          china raise crop price increase output
# 11206                 australia sell tonne sugar ussr
# 11207                 thai natural rubber export rise
# 11208          australian beef output decline january
# 11209  german government need seen raising bond yield
# 11210         ussr cut coal price japanese steelmills
# 11211   placer pacific hope misima gold approval soon
# 11212         bangladesh trade deficit narrow october
# 11213    swiss industrial output rise fourth qquarter
# 11214          asian dollar asset exceed billion dlrs
# 11215             singapore money supply pct december
# 11216             chinese industrial growth rate weak
# 11217         new dutch advance total billion guilder
# 11218  iran selling discounted crude japan trader say
# 11219                           ici sell stake lister
#
#                                                     body
# 0      jaguar plc jagrl sell new model japanese marke...
# 1      commodity credit corporation ccc accepted bid ...
# 2      shr ct ct net rev mln avg shrs mln mln year sh...
# 3      earthquake hit northern chile today registerin...
# 4      orbit oil gas ltd said value oil gas reserve i...
# 5      commodity credit corporation ccc accepted bid ...
# 6      five consortium applied buy french stateowned ...
# 7      blizzard condition halted shipping bosphorus w...
# 8      sterling grace capital management group said c...
# 9      shr profit ct loss two ct net profit loss rev ...
# 10     shr ct dlrs net rev note shr november class su...
# 11     bank england said given money market mln stg a...
# 12     hutton group inc said started previously annou...
# 13     responsibility appreciation taiwan dollar sout...
# 14     shr diluted loss ct profit ct net loss profit ...
# 15     orangeco inc said largest shareholder summit r...
# 16     oper shr profit dlrs loss eight ct oper net pr...
# 17     shr net mln mln rev billion billion note figur...
# 18     shr loss dlrs nil net loss profit rev mln mln ...
# 19     trimedyne inc said distribute one class common...
# 20     shr ct ct net sale mln mln nine mths shr ct ct...
# 21     french operator requested licence export tonne...
# 22     diamond shamrock said raised posted price grad...
# 23     shr ct ct net sale mln mln year shr ct ct net ...
# 24     oper shr loss five ct loss ct oper net loss lo...
# 25     qtly div ct ct prior pay april record march re...
# 26     mannesmann mmwgf diversified engineering pipem...
# 27     shr dlrs ct net mln mln year shr dlrs dlrs net...
# 28     system health care inc said repositioned compa...
# 29     royal dutchshell group rdas earnings fell shar...
# ...                                                  ...
# 11190  opec member ecuador adopted austerity measure ...
# 11191  fading hope passenger trapped aboard partially...
# 11192  survivor british crosschannel ferry disaster b...
# 11193  shr cent cent interim dividend three cent grou...
# 11194  six month december shr cent cent interim divid...
# 11195  six month december shr ct interim dividend ct ...
# 11196  six month december shr ct ct interim dividend ...
# 11197  bangladesh sugar production increased nearly t...
# 11198  senior official west german coalition governme...
# 11199  yield day banker security deposit account issu...
# 11200  british government investigation got way sinki...
# 11201  turkey oil pipeline near southern town adana c...
# 11202  hundred marine alert key brazilian port seaman...
# 11203  suspension ecuador crude oil shipment earthqua...
# 11204  european community decision liberalise farm tr...
# 11205  china raised price pay farmer cotton edible oi...
# 11206  australia sold tonne raw sugar soviet union sh...
# 11207  thai natural rubber export rose tonne year ear...
# 11208  australian beef output declined tonne carcass ...
# 11209  increased federal government borrowing need gr...
# 11210  soviet union agreed cut coking coal export pri...
# 11211  placer pacific ltd said hope papua new guinea ...
# 11212  bangladesh trade deficit narrowed billion taka...
# 11213  swiss industrial output rose nine pct fourth q...
# 11214  asian dollar market continued expand december ...
# 11215  singapore money supply rose pct december billi...
# 11216  value china industrial output january february...
# 11217  dutch central bank said accepted bid totalling...
# 11218  japanese customer bought nearly six mln barrel...
# 11219  imperial chemical industry plc icil said today...
#
# [11220 rows x 4 columns]

# %%
from sklearn import preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
encoder = preprocessing.LabelEncoder()
tfidf_vector = TfidfVectorizer(analyzer = 'word',
                               token_pattern = r'\w{1,}',
                               max_features = 5000, 
                              lowercase = False)

# %%
doc['label'] = encoder.fit_transform(doc['topic'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    tfidf_vect, doc['label'], test_size = 0.25,
    random_state = 28)
actual = y_test

# %%
#change variable type and pass
tfidf_vector = tfidf_vector.fit(doc['body'])
X_train_tfidf = tfidf_vector.transform(X_train)
X_test_tfidf = tfidf_vector.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-1876b8a9c29f> in <module>()
#       1 tfidf_vector = tfidf_vector.fit(doc['body'])
# ----> 2 X_train_tfidf = tfidf_vector.transform(X_train)
#       3 X_test_tfidf = tfidf_vector.transform(X_test)
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents, copy)
#    1609         check_is_fitted(self, '_tfidf', 'The tfidf vector is not fitted')
#    1610
# -> 1611         X = super(TfidfVectorizer, self).transform(raw_documents)
#    1612         return self._tfidf.transform(X, copy=False)
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents)
#    1064
#    1065         # use the same matrix-building strategy as fit_transform
# -> 1066         _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#    1067         if self.binary:
#    1068             X.data.fill(1)
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     920         for doc in raw_documents:
#     921             feature_counter = {}
# --> 922             for feature in analyze(doc):
#     923                 try:
#     924                     feature_idx = vocabulary[feature]
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     306                                                tokenize)
#     307             return lambda doc: self._word_ngrams(
# --> 308                 tokenize(preprocess(self.decode(doc))), stop_words)
#     309
#     310         else:
#
# ~/anaconda3/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     263             return self.tokenizer
#     264         token_pattern = re.compile(self.token_pattern)
# --> 265         return lambda doc: token_pattern.findall(doc)
#     266
#     267     def get_stop_words(self):
#
# TypeError: cannot use a string pattern on a bytes-like object

# %%
tfidf_fit
# Out:
# <11220x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 539418 stored elements in Compressed Sparse Row format>

# %%
svcmod = SVC(kernel = 'rbf', C=0.1, gamma = 'auto')
svcfit = svcmod.fit(X_train, y_train)
svc_pred = svcfit.predict(X_test)
accuracy_score(actual, svc_pred)

# %%
mnb_mod = MultinomialNB()
mnb_fit = mnb_mod.fit(X_train, y_train)

# %%
mnb_score = accuracy_score(actual, mnb_fit.predict(X_test))

# %%
mnb_score
# Out:
# 0.9818181818181818

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmod = LogisticRegression()
logfit = logmod.fit(X_train, y_train)
accuracy_score(actual, logfit.predict(X_test))
# Out:
# /Users/Avinash/anaconda3/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Avinash/anaconda3/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:459: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 1.0

# %%
logfit.predict(X_test)
# Out:
# array([ 8, 22,  8, ...,  0,  8,  0])

# %%
rfmod = RandomForestClassifier()
rffit = rfmod.fit(X_train, y_train)
rf_score = accuracy_score(actual, rffit.predict(X_test))
rf_score
# Out:
# /Users/Avinash/anaconda3/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 1.0

# %%
mnb_fit.predict(X_test)
# Out:
# array([ 8, 22,  8, ...,  0,  8,  0])
